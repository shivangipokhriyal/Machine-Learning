# %% [markdown]
# <a href="https://colab.research.google.com/github/shivangipokhriyal/Machine-Learning/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# visualisation libraries
import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import folium
from folium import plugins

# manipulating  default plot size
plt.rcParams['figure.figsize']=10, 12

# Disable warnimgs
import warnings
warnings.filterwarnings('ignore')

# %%
from datetime import datetime
import os
import re
import glob
import requests
from bs4 import BeautifulSoup

# %%
link = 'https://www.mohfw.gov.in/'
req = requests.get(link)
# parse web data
soup= BeautifulSoup(req.content, "html.parser")

# %%
# out target table is the last table in the page

# get table head which may contain column names, titles, subtitles
thead = soup.find_all('thead')[-1]
# get all the rows in table head
head = thead.find_all('tr')
# print(head)

# get table body
tbody= soup.find_all('tbody')[-1]
# get all thge rows in table body
# each row is each state's entry
body = tbody.find_all('tr')
# print(body)

# %%
# get table contents
head_rows= []
body_rows=[]
# loop through head and appemd each row to head
for tr in head:
  td = tr.find_all(['th', 'td'])
  row= [i.text for i in td]
  head_rows.append(row)
  #print(head_rows)

# loop through head and appemd each row to body
for tr in body:
  td = tr.find_all(['th', 'td'])
  row= [i.text for i in td]
  body_rows.append(row)
  # print(body_rows)

# %%
# save contents in data frame
df_bs = pd.DataFrame(body_rows[: len(body_rows)-6], 
                      columns=head_rows[0])
df_bs.drop('S. No.', axis=1, inplace= True)
df_bs.head(36)
# Out:
#                           Name of State / UT  ... Total Confirmed cases*
# 0                Andaman and Nicobar Islands  ...                     45
# 1                             Andhra Pradesh  ...                   7961
# 2                          Arunachal Pradesh  ...                    103
# 3                                      Assam  ...                   4904
# 4                                      Bihar  ...                   7181
# 5                                 Chandigarh  ...                    381
# 6                               Chhattisgarh  ...                   2028
# 7   Dadra and Nagar Haveli and Daman and Diu  ...                     62
# 8                                      Delhi  ...                  53116
# 9                                        Goa  ...                    725
# 10                                   Gujarat  ...                  26141
# 11                                   Haryana  ...                   9743
# 12                          Himachal Pradesh  ...                    619
# 13                         Jammu and Kashmir  ...                   5680
# 14                                 Jharkhand  ...                   1965
# 15                                 Karnataka  ...                   8281
# 16                                    Kerala  ...                   2912
# 17                                    Ladakh  ...                    744
# 18                            Madhya Pradesh  ...                  11582
# 19                               Maharashtra  ...                 124331
# 20                                   Manipur  ...                    681
# 21                                 Meghalaya  ...                     44
# 22                                   Mizoram  ...                    130
# 23                                  Nagaland  ...                    198
# 24                                    Odisha  ...                   4677
# 25                                Puducherry  ...                    286
# 26                                    Punjab  ...                   3832
# 27                                 Rajasthan  ...                  14156
# 28                                    Sikkim  ...                     70
# 29                                Tamil Nadu  ...                  54449
# 30                                 Telangana  ...                   6526
# 31                                   Tripura  ...                   1178
# 32                               Uttarakhand  ...                   2177
# 33                             Uttar Pradesh  ...                  15785
# 34                               West Bengal  ...                  13090
#
# [35 rows x 5 columns]

# %%
df_India = df_bs.copy()

now= datetime.now()
# date format
df_India['Date']=  now.strftime("%m/%d/%Y")
# add date column to data frame
df_India['Date'] =  pd.to_datetime(df_India['Date'], format='%m/%d/%Y')
#df_India.head(36)

# %%
# remove extra characters from name of state/ut column
df_India['Name of State / UT']= df_India['Name of State / UT'].str.replace('#','')
df_India['Deaths**']=df_India['Deaths**'].str.replace("#",'')

# %%
#latitude of states
lat = { 'Delhi':28.7041,'Haryana':29.0588, 'Kerala':10.8505, 'Rajasthan' :27.0238,
       'Telengana':18.1124, 'Uttar Pradesh' :26.8467, 'Ladakh':34.2996, 'Tamil Nadu' :11.1271, 
       'Jammu and Kashmir': 33.7782 ,'Punjab' :31.1471, 'Karnataka':15.3173, 'Maharashtra':19.7515, 
       'Andhra Pradesh':15.9129,'Odisha' :20.9517, 'Uttarakhand':30.0668,  'West Bengal':22.9868, 
       'Puducherry' : 11.9416, 'Chandigarh': 30.7333, 'Chhattisgarh':21.2787, 'Gujarat': 22.2587, 
       'Himachal Pradesh': 31.1048, 'Madhya Pradesh': 22.9734, 'Bihar': 25.0961, 'Manipur':24.6637, 
       'Mizoram':23.1645, 'Goa':15.2993, 'Andaman and Nicobar Islands': 11.7401, 'Assam' : 26.2006, 
       'Jharkhand' : 23.6102,'Arunachal Pradesh': 28.2180, 'Tripura': 23.9408, 'Nagaland': 26.1584, 
       'Meghalaya' : 25.4670, 'Dadar Nagar Haveli' : 20.1809, 'Sikkim': 27.5330} 
#longitude
long = { 'Delhi':77.1025,'Haryana':76.0856, 'Kerala':76.2711, 'Rajasthan' :74.2179,
       'Telengana':79.0193, 'Uttar Pradesh' :80.9462, 'Ladakh':78.2932, 'Tamil Nadu':78.6569,
        'Jammu and Kashmir':76.5762, 'Punjab' :75.3412, 'Karnataka':75.7139, 'Maharashtra' :75.7139, 
        'Andhra Pradesh':79.7400, 'Odisha' :85.0985, 'Uttarakhand' :79.0193, 'West Bengal':87.8550, 
        'Puducherry': 79.8083, 'Chandigarh': 76.7794, 'Chhattisgarh' : 81.8661, 'Gujarat': 71.1924, 
        'Himachal Pradesh': 77.1734, 'Madhya Pradesh': 78.6569, 'Bihar': 85.3131, 'Manipur' :93.9063, 
        'Mizoram':92.9376, 'Goa': 741240, 'Andaman and Nicobar Islands': 92.6586, 'Assam' : 92.9376, 
        'Jharkhand': 85.2799, 'Arunachal Pradesh': 94.7278, 'Tripura': 91.9882, 'Nagaland': 94.5624, 
        'Meghalaya' : 91.3662, 'Dadar Nagar Haveli' : 73.0169, 'Sikkim': 88.5122}

df_India['Latitude'] = df_India['Name of State / UT'].map(lat)
df_India['Longitude']= df_India['Name of State / UT'].map(long)
df_India.head(36)
# Out:
#                           Name of State / UT  ...    Longitude
# 0                Andaman and Nicobar Islands  ...      92.6586
# 1                             Andhra Pradesh  ...      79.7400
# 2                          Arunachal Pradesh  ...      94.7278
# 3                                      Assam  ...      92.9376
# 4                                      Bihar  ...      85.3131
# 5                                 Chandigarh  ...      76.7794
# 6                               Chhattisgarh  ...      81.8661
# 7   Dadra and Nagar Haveli and Daman and Diu  ...          NaN
# 8                                      Delhi  ...      77.1025
# 9                                        Goa  ...  741240.0000
# 10                                   Gujarat  ...      71.1924
# 11                                   Haryana  ...      76.0856
# 12                          Himachal Pradesh  ...      77.1734
# 13                         Jammu and Kashmir  ...      76.5762
# 14                                 Jharkhand  ...      85.2799
# 15                                 Karnataka  ...      75.7139
# 16                                    Kerala  ...      76.2711
# 17                                    Ladakh  ...      78.2932
# 18                            Madhya Pradesh  ...      78.6569
# 19                               Maharashtra  ...      75.7139
# 20                                   Manipur  ...      93.9063
# 21                                 Meghalaya  ...      91.3662
# 22                                   Mizoram  ...      92.9376
# 23                                  Nagaland  ...      94.5624
# 24                                    Odisha  ...      85.0985
# 25                                Puducherry  ...      79.8083
# 26                                    Punjab  ...      75.3412
# 27                                 Rajasthan  ...      74.2179
# 28                                    Sikkim  ...      88.5122
# 29                                Tamil Nadu  ...      78.6569
# 30                                 Telangana  ...          NaN
# 31                                   Tripura  ...      91.9882
# 32                               Uttarakhand  ...      79.0193
# 33                             Uttar Pradesh  ...      80.9462
# 34                               West Bengal  ...      87.8550
#
# [35 rows x 8 columns]

# %%
# rename columns
df_India = df_India.rename( columns={ 'Cured/Discharged/Migrated':'Cured',
                                        'Total Confirmed cases *':'Confirmed',
                                         'Total Confirmed cases ':'Confirmed',
                                        'Total Confirmed cases*':'Confirmed'})
df_India=df_India.rename(columns={'Cured/Discharged':'Cured'})
df_India= df_India.rename(columns={'Name of State / UT': 'State/UnionTerritory'})
df_India= df_India.rename(columns=lambda x:re.sub('Total Confirmed cases \(Including .* foreign Nationals\)','Total Confirmed cases', x))
df_India = df_India.rename( columns= {'Deaths (more that 70% cases due to comorbidities )' : 'Deaths', 'Deaths**':'Deaths'})
#df_India.head(1)

# %%
#unique state names
df_India['State/UnionTerritory'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttarakhand',
#        'Uttar Pradesh', 'West Bengal'], dtype=object)

# %%
#number of missing values
df_India.isna().sum()
# Out:
# State/UnionTerritory    0
# Active Cases*           0
# Cured                   0
# Deaths                  0
# Confirmed               0
# Date                    0
# Latitude                2
# Longitude               2
# dtype: int64

# %%
# number of unique values
df_India.nunique()
# Out:
# State/UnionTerritory    35
# Active Cases*           34
# Cured                   34
# Deaths                  25
# Confirmed               35
# Date                     1
# Latitude                33
# Longitude               30
# dtype: int64

# %%
#saving data

# file names as y-m-d.csv format
file_name = now.strftime("%Y_%m_%d")+' -COVID-19_India.csv'
#location for saving file
file_loc= '/content/'
# save file as csv file
df_India.to_csv(file_loc + file_name, index= False)

#df_India.head(36)

# %%
# fix datatype
df_India['Date']= pd.to_datetime(df_India['Date'])

# %%
# rename state/Ut names
df_India['State/UnionTerritory'].replace('Chattisgarh','Chhattisgarh', inplace=True)
df_India['State/UnionTerritory'].replace('Pondicherry','Puducherry', inplace=True)

# %%
df_India.head(36)
# Out:
#                         State/UnionTerritory  ...    Longitude
# 0                Andaman and Nicobar Islands  ...      92.6586
# 1                             Andhra Pradesh  ...      79.7400
# 2                          Arunachal Pradesh  ...      94.7278
# 3                                      Assam  ...      92.9376
# 4                                      Bihar  ...      85.3131
# 5                                 Chandigarh  ...      76.7794
# 6                               Chhattisgarh  ...      81.8661
# 7   Dadra and Nagar Haveli and Daman and Diu  ...          NaN
# 8                                      Delhi  ...      77.1025
# 9                                        Goa  ...  741240.0000
# 10                                   Gujarat  ...      71.1924
# 11                                   Haryana  ...      76.0856
# 12                          Himachal Pradesh  ...      77.1734
# 13                         Jammu and Kashmir  ...      76.5762
# 14                                 Jharkhand  ...      85.2799
# 15                                 Karnataka  ...      75.7139
# 16                                    Kerala  ...      76.2711
# 17                                    Ladakh  ...      78.2932
# 18                            Madhya Pradesh  ...      78.6569
# 19                               Maharashtra  ...      75.7139
# 20                                   Manipur  ...      93.9063
# 21                                 Meghalaya  ...      91.3662
# 22                                   Mizoram  ...      92.9376
# 23                                  Nagaland  ...      94.5624
# 24                                    Odisha  ...      85.0985
# 25                                Puducherry  ...      79.8083
# 26                                    Punjab  ...      75.3412
# 27                                 Rajasthan  ...      74.2179
# 28                                    Sikkim  ...      88.5122
# 29                                Tamil Nadu  ...      78.6569
# 30                                 Telangana  ...          NaN
# 31                                   Tripura  ...      91.9882
# 32                               Uttarakhand  ...      79.0193
# 33                             Uttar Pradesh  ...      80.9462
# 34                               West Bengal  ...      87.8550
#
# [35 rows x 8 columns]

# %%
# to get info
df_India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State/UnionTerritory  35 non-null     object
#  1   Active Cases*         35 non-null     object
#  2   Cured                 35 non-null     object
#  3   Deaths                35 non-null     object
#  4   Confirmed             35 non-null     object
#  5   Date                  35 non-null     datetime64[ns]
#  6   Latitude              33 non-null     float64
#  7   Longitude             33 non-null     float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 2.3+ KB

# %%
#save as .csv file

# file names as y-m-d.csv format
file_name = now.strftime("%Y_%m_%d")+' -COVID-19_India_preprocessed.csv'
#location for saving file
file_loc= '/content/'
# save file as csv file
df_India.to_csv(file_loc + file_name, index= False)

#df_India.head(36)

# %%
# learn to create .csv file by creating a dataframe using pandas
#reading the datasets
df= pd.read_csv('/content/2020_06_20 -COVID-19_India_preprocessed.csv')
df_india=df.copy()
df
# Out:
#                         State/UnionTerritory  ...    Longitude
# 0                Andaman and Nicobar Islands  ...      92.6586
# 1                             Andhra Pradesh  ...      79.7400
# 2                          Arunachal Pradesh  ...      94.7278
# 3                                      Assam  ...      92.9376
# 4                                      Bihar  ...      85.3131
# 5                                 Chandigarh  ...      76.7794
# 6                               Chhattisgarh  ...      81.8661
# 7   Dadra and Nagar Haveli and Daman and Diu  ...          NaN
# 8                                      Delhi  ...      77.1025
# 9                                        Goa  ...  741240.0000
# 10                                   Gujarat  ...      71.1924
# 11                                   Haryana  ...      76.0856
# 12                          Himachal Pradesh  ...      77.1734
# 13                         Jammu and Kashmir  ...      76.5762
# 14                                 Jharkhand  ...      85.2799
# 15                                 Karnataka  ...      75.7139
# 16                                    Kerala  ...      76.2711
# 17                                    Ladakh  ...      78.2932
# 18                            Madhya Pradesh  ...      78.6569
# 19                               Maharashtra  ...      75.7139
# 20                                   Manipur  ...      93.9063
# 21                                 Meghalaya  ...      91.3662
# 22                                   Mizoram  ...      92.9376
# 23                                  Nagaland  ...      94.5624
# 24                                    Odisha  ...      85.0985
# 25                                Puducherry  ...      79.8083
# 26                                    Punjab  ...      75.3412
# 27                                 Rajasthan  ...      74.2179
# 28                                    Sikkim  ...      88.5122
# 29                                Tamil Nadu  ...      78.6569
# 30                                 Telangana  ...          NaN
# 31                                   Tripura  ...      91.9882
# 32                               Uttarakhand  ...      79.0193
# 33                             Uttar Pradesh  ...      80.9462
# 34                               West Bengal  ...      87.8550
#
# [35 rows x 8 columns]

# %%
# ANALYSING THE DATA

# %%
total_cases = df['Confirmed'].sum()
print('Total number of confirmed COVID 2019 cases across India till date:',total_cases)
# Out:
# Total number of confirmed COVID 2019 cases across India till date: 385783

# %%
# how to highlight your dataframe
df_temp = df.drop(['Latitude','Longitude','Date','Active Cases*'], axis = 1)
# above code removes date latitude and  longitude and other extra columns
df_temp.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row1_col1 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row1_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row1_col3 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row2_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row3_col1 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row3_col3 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row4_col1 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row4_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row4_col3 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row5_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row6_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row6_col3 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row7_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row7_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row7_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row8_col1 {
#             background-color:  #fc9272;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row8_col2 {
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row8_col3 {
#             background-color:  #fc8161;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row9_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row9_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row10_col1 {
#             background-color:  #fcae92;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row10_col2 {
#             background-color:  #fcb398;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row10_col3 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row11_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row11_col2 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row11_col3 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row12_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row12_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row12_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row13_col1 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row13_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row13_col3 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row14_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row14_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row14_col3 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row15_col1 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row15_col2 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row15_col3 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row16_col1 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row16_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row16_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row17_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row17_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row17_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row18_col1 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row18_col2 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row18_col3 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row19_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row19_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_bab585f8_b2e5_11ea_b8ba_0242ac1c0002row19_col3 {
#             background-color:  #67000d;

# %%
today= now.strftime("%y/%m/d")
total_cured= df['Cured'].sum()
print("Total people who have been cured as of "+today+" are: ", total_cured)
total_cases= df['Confirmed'].sum()
print("Total number of people who were detected COVID +ve as of "+today+" are: ", total_cases)
atotal_death = df['Deaths'].sum()
print("Total people who died due to COVID19 as of "+today+" are: ",total_death)
total_active = total_cases - total_cured - total_death
print("Toatl active cases as of "+today+" are: ",total_active)
# Out:
# Total people who have been cured as of 20/06/d are:  213831
# Total number of people who were detected COVID +ve as of 20/06/d are:  385783
# Total people who died due to COVID19 as of 20/06/d are:  12948
# Toatl active cases as of 20/06/d are:  159004

# %%
# toatla ctive cases= no. of death + cured
df['Total Active']= df['Confirmed']- (df['Deaths']+ df['Cured'])
total_active= df['Total Active'].sum()
print('Total number of active COVID 19 cases across /india are: ', total_active)
Tot_Cases = df.groupby('State/UnionTerritory')['Total Active'].sum().sort_values(ascending=False).to_frame()
Tot_Cases.style.background_gradient(cmap='Reds')
# Out:
# Total number of active COVID 19 cases across /india are:  159004
# <style  type="text/css" >
#     #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row1_col0 {
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row2_col0 {
#             background-color:  #fc8262;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row3_col0 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row4_col0 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row5_col0 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row6_col0 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row7_col0 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row8_col0 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row9_col0 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row10_col0 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row11_col0 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row12_col0 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row13_col0 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row14_col0 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row15_col0 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row16_col0 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row17_col0 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row18_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row19_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row20_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row21_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row22_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row23_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row24_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row25_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row26_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row27_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row28_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row29_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row30_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row31_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row32_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row33_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row34_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Active</th>    </tr>    <tr>        <th class="index_name level0" >State/UnionTerritory</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row0" class="row_heading level0 row0" >Maharashtra</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row0_col0" class="data row0 col0" >55665</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row1" class="row_heading level0 row1" >Delhi</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row1_col0" class="data row1 col0" >27512</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row2" class="row_heading level0 row2" >Tamil Nadu</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row2_col0" class="data row2 col0" >23512</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row3" class="row_heading level0 row3" >Gujarat</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row3_col0" class="data row3 col0" >6364</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row4" class="row_heading level0 row4" >Uttar Pradesh</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row4_col0" class="data row4 col0" >5659</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row5" class="row_heading level0 row5" >West Bengal</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row5_col0" class="data row5 col0" >5258</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row6" class="row_heading level0 row6" >Haryana</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row6_col0" class="data row6 col0" >4710</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row7" class="row_heading level0 row7" >Andhra Pradesh</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row7_col0" class="data row7 col0" >3948</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row8" class="row_heading level0 row8" >Telangana</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row8_col0" class="data row8 col0" >2975</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row9" class="row_heading level0 row9" >Karnataka</th>
#                         <td id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002row9_col0" class="data row9 col0" >2947</td>
#             </tr>
#             <tr>
#                         <th id="T_ef17fa72_b2f1_11ea_b8ba_0242ac1c0002level0_row10" class="row_heading level0 row10" >Rajasthan</th>

# %%
import numpy as np
state_cases= df_india.groupby('State/UnionTerritory')['Confirmed','Deaths', 'Cured'].max().reset_index()

#state_cases = state_cases.astype({'Deaths':'int'})
state_cases['Active']= state_cases['Confirmed']- (state_cases['Deaths']+state_cases['Cured'])
state_cases['Death Rate (per 100)']= np.round(100*state_cases["Deaths"]/state_cases['Confirmed'],2)
state_cases['Cure Rate (per 100)']= np.round(100*state_cases["Cured"]/state_cases['Confirmed'],2)
state_cases.sort_values('Confirmed', ascending=False).fillna(0).style.background_gradient(cmap='Blues', subset=['Confirmed'])\
                         .background_gradient(cmap='Blues', subset=["Deaths"])\
                         .background_gradient(cmap='Blues', subset=["Cured"])\
                         .background_gradient(cmap='Blues', subset=["Active"])\
                         .background_gradient(cmap='Blues', subset=["Death Rate (per 100)"])\
                         .background_gradient(cmap='Blues', subset=["Cure Rate (per 100)"])
# Out:
# <style  type="text/css" >
#     #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row0_col5 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row0_col6 {
#             background-color:  #4896c8;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row1_col1 {
#             background-color:  #84bcdb;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row1_col2 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row1_col3 {
#             background-color:  #72b2d8;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row1_col4 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row1_col5 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row1_col6 {
#             background-color:  #3686c0;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row2_col1 {
#             background-color:  #89bedc;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row2_col2 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row2_col3 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row2_col4 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row2_col5 {
#             background-color:  #4493c7;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row2_col6 {
#             background-color:  #60a7d2;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row3_col1 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row3_col2 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row3_col3 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row3_col4 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row3_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row3_col6 {
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row4_col1 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row4_col2 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row4_col3 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row4_col4 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row4_col5 {
#             background-color:  #6caed6;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row4_col6 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row5_col1 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row5_col2 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row5_col3 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row5_col4 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row5_col5 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row5_col6 {
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row6_col1 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row6_col2 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row6_col3 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row6_col4 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row6_col5 {
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row6_col6 {
#             background-color:  #3686c0;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row7_col1 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row7_col2 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row7_col3 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row7_col4 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row7_col5 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row7_col6 {
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row8_col1 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row8_col2 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row8_col3 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row8_col4 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row8_col5 {
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row8_col6 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row9_col1 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row9_col2 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row9_col3 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row9_col4 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row9_col5 {
#             background-color:  #c7dcef;
#             color:  #000000;
#         }    #T_e75e1862_b2f5_11ea_b8ba_0242ac1c0002row9_col6 {
#             background-color:  #1f6eb3;
#             color:  #f1f1f1;

# %%
df['Confirmed']
# Out:
# 0         45
# 1       7961
# 2        103
# 3       4904
# 4       7181
# 5        381
# 6       2028
# 7         62
# 8      53116
# 9        725
# 10     26141
# 11      9743
# 12       619
# 13      5680
# 14      1965
# 15      8281
# 16      2912
# 17       744
# 18     11582
# 19    124331
# 20       681
# 21        44
# 22       130
# 23       198
# 24      4677
# 25       286
# 26      3832
# 27     14156
# 28        70
# 29     54449
# 30      6526
# 31      1178
# 32      2177
# 33     15785
# 34     13090
# Name: Confirmed, dtype: int64
